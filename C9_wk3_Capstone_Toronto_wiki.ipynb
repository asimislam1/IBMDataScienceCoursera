# %% [markdown]
# # C9_wk3_Capstone_Toronto_wiki
# Course 9:  Peer-graded Assignment: Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# ##   TASK 1:  Create DataFrame from wiki page (Toronto)

# %% [markdown]
# __Import Libraries__

# %%
import pandas as pd
from bs4 import BeautifulSoup  # scrape websites
import requests

# %% [markdown]
# __steps 1 & 2:  Scrape the WIKI page__

# %%
#===================================================
#  STEP 1:  Create notebook
#  STEP 2:  Scrape wiki page
#===================================================
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
wiki_html = requests.get(url).text
soup = BeautifulSoup(wiki_html, 'lxml')

#  Inspecting the wiki page to determine the tags
#  We need 'tr' and 'td' tags in our loop
#soup.tbody.find('tr')
#soup.tbody.find_all('tr')[4]
#soup.tbody.find_all('tr')[4].find_all('td')

df_wiki = []
for tr in soup.tbody.find_all('tr'):
    df_wiki.append([ td.get_text().strip() for td in tr.find_all('td')])
    
df_wiki[0:4]
# Out:
# [[],
#  ['M1A', 'Not assigned', 'Not assigned'],
#  ['M2A', 'Not assigned', 'Not assigned'],
#  ['M3A', 'North York', 'Parkwoods']]

# %% [markdown]
# __step 3:  Setup the DataFrame__

# %%
#  Step 3:  Setup the data frame
#===================================================
df = pd.DataFrame(data=df_wiki, columns=['PostalCode','Borough','Neighborhood'])
print(df.info())
print(df.head())
print(df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 3 columns):
# PostalCode      288 non-null object
# Borough         288 non-null object
# Neighborhood    288 non-null object
# dtypes: object(3)
# memory usage: 6.9+ KB
# None
#   PostalCode       Borough      Neighborhood
# 0       None          None              None
# 1        M1A  Not assigned      Not assigned
# 2        M2A  Not assigned      Not assigned
# 3        M3A    North York         Parkwoods
# 4        M4A    North York  Victoria Village
# (289, 3)

# %%
#   Ignore Boroughs that are 'Not assigned'
#-----------------------------------------
df = df[df['Borough'] != 'Not assigned']

# %%
#  Group Neighborhoods per PostalCode
#-----------------------------------------
#  code example from https://stackoverflow.com/questions/51584363/
df = df.groupby('PostalCode')['Borough','Neighborhood'].agg(lambda x: ', '.join(set(x))).reset_index()

print("PostalCode:\t",len(df['PostalCode'].unique()))
print("Borough:\t",len(df['Borough'].unique()))
print("Neighborhood:\t",len(df['Neighborhood'].unique()))
# Out:
# PostalCode:	 103
# Borough:	 11
# Neighborhood:	 103

# %%
#  "Not assigned" neighborhood, will be the same as the borough
#-----------------------------------------
df.Neighborhood[df.Neighborhood == 'Not assigned']    # look for "Not assigned"
df.Neighborhood[df.Neighborhood == 'Not assigned'] = df.Borough[df.Neighborhood == 'Not assigned']   # replace

df[df['Neighborhood'] == 'Queen\'s Park']  #  check
# Out:
#    PostalCode       Borough  Neighborhood
# 85        M7A  Queen's Park  Queen's Park

# %%
#  make sure that there are no 'Neighborhood' == 'Not assigned'
df[df['Neighborhood'] == 'Not assigned']   #  check
# Out:
# Empty DataFrame
# Columns: [PostalCode, Borough, Neighborhood]
# Index: []

# %% [markdown]
# __Print out the DataFrame__

# %%
df.head(df.shape[0])
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# 27         M3C        North York
# 28         M3H        North York
# 29         M3J        North York
# ..         ...               ...
# 73         M6C              York
# 74         M6E              York
# 75         M6G  Downtown Toronto
# 76         M6H      West Toronto
# 77         M6J      West Toronto
# 78         M6K      West Toronto
# 79         M6L        North York
# 80         M6M              York
# 81         M6N              York
# 82         M6P      West Toronto
# 83         M6R      West Toronto
# 84         M6S      West Toronto
# 85         M7A      Queen's Park
# 86         M7R       Mississauga
# 87         M7Y      East Toronto
# 88         M8V         Etobicoke
# 89         M8W         Etobicoke
# 90         M8X         Etobicoke
# 91         M8Y         Etobicoke
# 92         M8Z         Etobicoke
# 93         M9A         Etobicoke
# 94         M9B         Etobicoke
# 95         M9C         Etobicoke
# 96         M9L        North York
# 97         M9M        North York
# 98         M9N              York
# 99         M9P         Etobicoke
# 100        M9R         Etobicoke
# 101        M9V         Etobicoke
# 102        M9W         Etobicoke
#
#                                           Neighborhood
# 0                                       Malvern, Rouge
# 1               Port Union, Highland Creek, Rouge Hill
# 2                    Guildwood, Morningside, West Hill
# 3                                               Woburn
# 4                                            Cedarbrae
# 5                                  Scarborough Village
# 6          East Birchmount Park, Kennedy Park, Ionview
# 7                      Clairlea, Golden Mile, Oakridge
# 8      Cliffside, Scarborough Village West, Cliffcrest
# 9                          Birch Cliff, Cliffside West
# 10   Dorset Park, Scarborough Town Centre, Wexford ...
# 11                                   Wexford, Maryvale
# 12                                           Agincourt
# 13             Tam O'Shanter, Clarks Corners, Sullivan
# 14   Milliken, L'Amoreaux East, Agincourt North, St...
# 15                                     L'Amoreaux West
# 16                                         Upper Rouge
# 17                                   Hillcrest Village
# 18                        Oriole, Fairview, Henry Farm
# 19                                     Bayview Village
# 20                            York Mills, Silver Hills
# 21                             Newtonbrook, Willowdale
# 22                                    Willowdale South
# 23                                     York Mills West
# 24                                     Willowdale West
# 25                                           Parkwoods
# 26                                     Don Mills North
# 27                    Don Mills South, Flemingdon Park
# 28     Downsview North, Wilson Heights, Bathurst Manor
# 29                     Northwood Park, York University
# ..                                                 ...
# 73                                  Humewood-Cedarvale
# 74                                 Caledonia-Fairbanks
# 75                                            Christie
# 76                        Dufferin, Dovercourt Village
# 77                            Little Portugal, Trinity
# 78        Brockton, Exhibition Place, Parkdale Village
# 79                  Upwood Park, North Park, Downsview
# 80      Del Ray, Keelesdale, Silverthorn, Mount Dennis
# 81                       The Junction North, Runnymede
# 82                       High Park, The Junction South
# 83                              Parkdale, Roncesvalles
# 84                                  Swansea, Runnymede
# 85                                        Queen's Park
# 86               Canada Post Gateway Processing Centre
# 87   Business Reply Mail Processing Centre 969 Eastern
# 88        New Toronto, Mimico South, Humber Bay Shores
# 89                              Long Branch, Alderwood
# 90       Montgomery Road, The Kingsway, Old Mill North
# 91   King's Mill Park, Royal York South East, Old M...
# 92   South of Bloor, Mimico NW, The Queensway West,...
# 93                                    Islington Avenue
# 94   Martin Grove, West Deane Park, Islington, Prin...
# 95   Bloordale Gardens, Eringate, Old Burnhamthorpe...
# 96                                       Humber Summit
# 97                                    Humberlea, Emery
# 98                                              Weston
# 99                                           Westmount
# 100  Richview Gardens, St. Phillips, Martin Grove G...
# 101  Jamestown, Albion Gardens, Mount Olive, Humber...
# 102                                          Northwest
#
# [103 rows x 3 columns]

# %% [markdown]
# __save dataframe to csv file__

# %%
df.to_csv('C:/Users/ACER/Desktop/JAVA/IBM_Certificate/labs/C9_wk3_Toronto_task1.csv',encoding='utf-8')

# %% [markdown]
# __Print number of rows using the .shape method.__

# %%
#Print number of rows
#-----------------------------------------
print("shape:\t",df.shape)      #  dimensions
print("rows:\t", df.shape[0])   #  number of rows
# Out:
# shape:	 (103, 3)
# rows:	 103

# %% [markdown]
# ## TASK 2: Use GeoCoder to Create DataFrame with Latitude/Longitude

# %% [markdown]
# __Import Libraries__

# %%
import geocoder
import folium

# %% [markdown]
# __Define function to use the Postal Code to get the latitude & longitude__
#
# (Using ARCGIS package...geocoder.google is very very slow)

# %%
#  Define function to get latitude & longitude using postal codes
def get_latlon(postal_code):
    # initialize your variable to None
    lat_lng_coords = None
    # loop until you get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.arcgis('{}, Toronto, Ontario'.format(postal_code))
        lat_lng_coords = g.latlng
        #print(postal_code,lat_lng_coords)
    return lat_lng_coords

get_latlon('M9B')   #  test function
# Out:
# [43.64969222700006, -79.55394499999994]

# %% [markdown]
# __Find location information for all postal codes__

# %%
postal_codes = df['PostalCode']

#  change postal_codes from series to list for the for loop
geo_latlon = [get_latlon(postal_code) for postal_code in postal_codes.tolist()]

# %% [markdown]
# __Create new dataframe for location and use it to update the original dataframe__

# %%
df_latlon = pd.DataFrame(data = geo_latlon, columns={'Latitude','Longitude'})
print(df_latlon.head())

#  Add Latitude and Longitude to the original dataframe
df['Latitude']  = df_latlon['Latitude']
df['Longitude'] = df_latlon['Longitude']
# Out:
#     Latitude  Longitude
# 0  43.811525 -79.195517
# 1  43.785730 -79.158750
# 2  43.765690 -79.175256
# 3  43.768359 -79.217590
# 4  43.769688 -79.239440

# %% [markdown]
# __Print out updated dataframe__

# %%
df.head(df.shape[0])
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# 27         M3C        North York
# 28         M3H        North York
# 29         M3J        North York
# ..         ...               ...
# 73         M6C              York
# 74         M6E              York
# 75         M6G  Downtown Toronto
# 76         M6H      West Toronto
# 77         M6J      West Toronto
# 78         M6K      West Toronto
# 79         M6L        North York
# 80         M6M              York
# 81         M6N              York
# 82         M6P      West Toronto
# 83         M6R      West Toronto
# 84         M6S      West Toronto
# 85         M7A      Queen's Park
# 86         M7R       Mississauga
# 87         M7Y      East Toronto
# 88         M8V         Etobicoke
# 89         M8W         Etobicoke
# 90         M8X         Etobicoke
# 91         M8Y         Etobicoke
# 92         M8Z         Etobicoke
# 93         M9A         Etobicoke
# 94         M9B         Etobicoke
# 95         M9C         Etobicoke
# 96         M9L        North York
# 97         M9M        North York
# 98         M9N              York
# 99         M9P         Etobicoke
# 100        M9R         Etobicoke
# 101        M9V         Etobicoke
# 102        M9W         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                       Malvern, Rouge  43.811525 -79.195517
# 1               Port Union, Highland Creek, Rouge Hill  43.785730 -79.158750
# 2                    Guildwood, Morningside, West Hill  43.765690 -79.175256
# 3                                               Woburn  43.768359 -79.217590
# 4                                            Cedarbrae  43.769688 -79.239440
# 5                                  Scarborough Village  43.743125 -79.231750
# 6          East Birchmount Park, Kennedy Park, Ionview  43.726245 -79.263670
# 7                      Clairlea, Golden Mile, Oakridge  43.713133 -79.285055
# 8      Cliffside, Scarborough Village West, Cliffcrest  43.723575 -79.234976
# 9                          Birch Cliff, Cliffside West  43.696665 -79.260163
# 10   Dorset Park, Scarborough Town Centre, Wexford ...  43.759975 -79.268974
# 11                                   Wexford, Maryvale  43.750710 -79.300560
# 12                                           Agincourt  43.793940 -79.267983
# 13             Tam O'Shanter, Clarks Corners, Sullivan  43.784725 -79.299047
# 14   Milliken, L'Amoreaux East, Agincourt North, St...  43.817810 -79.280244
# 15                                     L'Amoreaux West  43.800881 -79.320740
# 16                                         Upper Rouge  43.834215 -79.216701
# 17                                   Hillcrest Village  43.802845 -79.356236
# 18                        Oriole, Fairview, Henry Farm  43.780880 -79.347796
# 19                                     Bayview Village  43.781015 -79.380542
# 20                            York Mills, Silver Hills  43.757192 -79.379865
# 21                             Newtonbrook, Willowdale  43.791475 -79.413605
# 22                                    Willowdale South  43.768165 -79.407420
# 23                                     York Mills West  43.747855 -79.400062
# 24                                     Willowdale West  43.777695 -79.445797
# 25                                           Parkwoods  43.752440 -79.329271
# 26                                     Don Mills North  43.749195 -79.361905
# 27                    Don Mills South, Flemingdon Park  43.721425 -79.343453
# 28     Downsview North, Wilson Heights, Bathurst Manor  43.757565 -79.448191
# 29                     Northwood Park, York University  43.764665 -79.487183
# ..                                                 ...        ...        ...
# 73                                  Humewood-Cedarvale  43.692105 -79.430355
# 74                                 Caledonia-Fairbanks  43.688640 -79.451015
# 75                                            Christie  43.668781 -79.420710
# 76                        Dufferin, Dovercourt Village  43.665087 -79.438705
# 77                            Little Portugal, Trinity  43.648485 -79.417742
# 78        Brockton, Exhibition Place, Parkdale Village  43.639410 -79.424362
# 79                  Upwood Park, North Park, Downsview  43.713810 -79.488305
# 80      Del Ray, Keelesdale, Silverthorn, Mount Dennis  43.694545 -79.484643
# 81                       The Junction North, Runnymede  43.675825 -79.482052
# 82                       High Park, The Junction South  43.659975 -79.462874
# 83                              Parkdale, Roncesvalles  43.647870 -79.449762
# 84                                  Swansea, Runnymede  43.649885 -79.474929
# 85                                        Queen's Park  43.661102 -79.391035
# 86               Canada Post Gateway Processing Centre  43.648690 -79.385440
# 87   Business Reply Mail Processing Centre 969 Eastern  43.648690 -79.385440
# 88        New Toronto, Mimico South, Humber Bay Shores  43.609870 -79.498178
# 89                              Long Branch, Alderwood  43.601131 -79.538785
# 90       Montgomery Road, The Kingsway, Old Mill North  43.653690 -79.511117
# 91   King's Mill Park, Royal York South East, Old M...  43.632765 -79.489601
# 92   South of Bloor, Mimico NW, The Queensway West,...  43.624630 -79.526950
# 93                                    Islington Avenue  43.662242 -79.528379
# 94   Martin Grove, West Deane Park, Islington, Prin...  43.649692 -79.553945
# 95   Bloordale Gardens, Eringate, Old Burnhamthorpe...  43.648573 -79.578250
# 96                                       Humber Summit  43.759500 -79.556852
# 97                                    Humberlea, Emery  43.733760 -79.537522
# 98                                              Weston  43.704855 -79.517552
# 99                                           Westmount  43.696300 -79.530399
# 100  Richview Gardens, St. Phillips, Martin Grove G...  43.686915 -79.557276
# 101  Jamestown, Albion Gardens, Mount Olive, Humber...  43.743205 -79.584701
# 102                                          Northwest  43.711740 -79.579181
#
# [103 rows x 5 columns]

# %% [markdown]
# ## FOLIUM MAP
# __Create folium map of the Borough using the Postal Codes__

# %%
#  Generate Map of Boroughs based on Postal Codes
toronto_map = folium.Map(location=[df.Latitude.mean(), df.Longitude.mean()], zoom_start=10)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(df.Latitude, df.Longitude, df.Borough):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(toronto_map)

# display map
toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
